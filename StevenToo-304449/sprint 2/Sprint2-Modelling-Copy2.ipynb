# %% [markdown]
# ## Yelp Restaurant Reviews and Ratings Analysis
# ### Sprint2 - Modelling and Predictive analysis
# #### By Steven Too Heng Kwee  - 304449

# %% [markdown]
# ### (1). Importing all the necessary modules:

# %%
# IMPORTING ALL THE NECESSARY LIBRARIES AND PACKAGES
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
from nltk.corpus import stopwords
import string
import math
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix, accuracy_score, roc_auc_score, roc_curve
# %matplotlib inline

# %% [markdown]
# ### (2). Loading and seeing the dataset details:
#
# #### Use file 'review_TO_R.csv' generated in sprint1

# %%
# LOADING THE DATASET AND SEEING THE DETAILS
data = pd.read_csv('review_TO_R.csv')
# SHAPE OF THE DATASET
print("Shape of the dataset:")
print(data.shape)
# COLUMN NAMES
print("Column names:")
print(data.columns)
# DATATYPE OF EACH COLUMN
print("Datatype of each column:")
print(data.dtypes)
# SEEING FEW OF THE ENTRIES
print("Few dataset entries:")
print(data.head())
# DATASET SUMMARY
data.describe(include='all')
# Out:
# Shape of the dataset:
# (57047, 24)
# Column names:
# Index(['_id_x', 'business_id', 'cool', 'date', 'funny', 'review_id', 'stars_x',
#        'text', 'useful', 'user_id', '_id_y', 'address', 'attributes',
#        'categories', 'city', 'hours', 'is_open', 'latitude', 'longitude',
#        'name', 'postal_code', 'review_count', 'stars_y', 'state'],
#       dtype='object')
# Datatype of each column:
# _id_x            object
# business_id      object
# cool              int64
# date             object
# funny             int64
# review_id        object
# stars_x         float64
# text             object
# useful            int64
# user_id          object
# _id_y            object
# address          object
# attributes       object
# categories       object
# city             object
# hours            object
# is_open           int64
# latitude        float64
# longitude       float64
# name             object
# postal_code      object
# review_count      int64
# stars_y         float64
# state            object
# dtype: object
# Few dataset entries:
#                       _id_x             business_id  cool  \
# 0  5d34af2f05c8a038caf1cb40  3a7Qby_IX7sU7O6ZsQZeOQ     0
# 1  5d34af3605c8a038caf1dfe5  3a7Qby_IX7sU7O6ZsQZeOQ     1
# 2  5d34af2505c8a038caf1a198  3a7Qby_IX7sU7O6ZsQZeOQ     0
# 3  5d34af5205c8a038caf20309  3a7Qby_IX7sU7O6ZsQZeOQ     0
# 4  5d34af6c05c8a038caf22ae0  3a7Qby_IX7sU7O6ZsQZeOQ     0
#
#                   date  funny               review_id  stars_x  \
# 0  2018-08-14 04:13:05      0  PB4wv1eNEGXh8QFQCMnd1g      4.0
# 1  2018-01-22 00:02:19      0  mNjd9B7dVBGH5f_rKIRofg      4.0
# 2  2018-03-15 19:09:56      2  n9B9XWtqYy1s-nyV6qnGwQ      4.0
# 3  2018-10-03 23:13:59      0  hjSFsF9bxiRqf1OM73Gc7A      2.0
# 4  2018-02-02 02:41:52      0  nxzG0S6v2hkBB9iYIFSVoQ      3.0
#
#                                                 text  useful  \
# 0  The service here is impeccable. Our waitress w...       0
# 1  Decided to come check out the furniture and se...       3
# 2  My best friend and I came here to see what the...       4
# 3  I went there for lunch today.  They've changed...       0
# 4  All stars go to the decor and atmosphere of th...       3
#
#                   user_id  ...      city  \
# 0  CZqHG0JtP6pxK2ox7zpwVQ  ...   Toronto
# 1  TFxeEvpjMNQ3AWL49iMwtA  ...   Toronto
# 2  HxkWE8b1bJbSc4Ihmgy5dQ  ...   Toronto
# 3  BV2TQDbbgC5Mwgyoh3CHDA  ...   Toronto
# 4  Fsl7fnXttgugpoyuCJ0zkg  ...   Toronto
#
#                                                hours is_open   latitude  \
# 0  {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 1  {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 2  {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 3  {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 4  {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
#
#    longitude               name  postal_code  review_count  stars_y state
# 0 -79.454173  RH Courtyard Cafe      M6A 2T9            82      4.0    ON
# 1 -79.454173  RH Courtyard Cafe      M6A 2T9            82      4.0    ON
# 2 -79.454173  RH Courtyard Cafe      M6A 2T9            82      4.0    ON
# 3 -79.454173  RH Courtyard Cafe      M6A 2T9            82      4.0    ON
# 4 -79.454173  RH Courtyard Cafe      M6A 2T9            82      4.0    ON
#
# [5 rows x 24 columns]
#                            _id_x             business_id          cool  \
# count                      57047                   57047  57047.000000
# unique                     57047                    4912           NaN
# top     5d35d0a305c8a038ca4171ab  r_BrIgzYcwo1NAuG9dLbpg           NaN
# freq                           1                     600           NaN
# mean                         NaN                     NaN      0.528880
# std                          NaN                     NaN      3.379325
# min                          NaN                     NaN      0.000000
# 25%                          NaN                     NaN      0.000000
# 50%                          NaN                     NaN      0.000000
# 75%                          NaN                     NaN      0.000000
# max                          NaN                     NaN    177.000000
#
#                        date         funny               review_id  \
# count                 57047  57047.000000                   57047
# unique                56950           NaN                   57047
# top     2018-05-23 01:34:02           NaN  v85RkCG6h7mV-6-yAHK31A
# freq                      2           NaN                       1
# mean                    NaN      0.229758                     NaN
# std                     NaN      1.801161                     NaN
# min                     NaN      0.000000                     NaN
# 25%                     NaN      0.000000                     NaN
# 50%                     NaN      0.000000                     NaN
# 75%                     NaN      0.000000                     NaN
# max                     NaN    124.000000                     NaN
#
#              stars_x                                               text  \
# count   57047.000000                                              57047
# unique           NaN                                              56958
# top              NaN  This small and unassuming place blew me away! ...
# freq             NaN                                                  3
# mean        3.705646                                                NaN
# std         1.307620                                                NaN
# min         1.000000                                                NaN
# 25%         3.000000                                                NaN
# 50%         4.000000                                                NaN
# 75%         5.000000                                                NaN
# max         5.000000                                                NaN
#
#               useful                 user_id  ...       city  \
# count   57047.000000                   57047  ...      57047
# unique           NaN                   22254  ...          1
# top              NaN  iRQ_YKpCBdaCwvc2X8_3NQ  ...    Toronto
# freq             NaN                     123  ...      57047
# mean        0.955493                     NaN  ...        NaN
# std         3.964542                     NaN  ...        NaN
# min         0.000000                     NaN  ...        NaN
# 25%         0.000000                     NaN  ...        NaN
# 50%         0.000000                     NaN  ...        NaN
# 75%         1.000000                     NaN  ...        NaN
# max       188.000000                     NaN  ...        NaN
#
#                                                     hours       is_open  \
# count                                               53487  57047.000000
# unique                                               2778           NaN
# top     {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...           NaN
# freq                                                 1111           NaN
# mean                                                  NaN      0.971234
# std                                                   NaN      0.167149
# min                                                   NaN      0.000000
# 25%                                                   NaN      1.000000
# 50%                                                   NaN      1.000000
# 75%                                                   NaN      1.000000
# max                                                   NaN      1.000000
#
#             latitude     longitude                       name  postal_code  \
# count   57047.000000  57047.000000                      57047        57028
# unique           NaN           NaN                       4060         2459
# top              NaN           NaN  Pai Northern Thai Kitchen      M6A 2T9
# freq             NaN           NaN                        600          642
# mean       43.680277    -79.388998                        NaN          NaN
# std         0.049278      0.050575                        NaN          NaN
# min        43.592327    -79.680563                        NaN          NaN
# 25%        43.649166    -79.410760                        NaN          NaN
# 50%        43.657648    -79.391842                        NaN          NaN
# 75%        43.684581    -79.378093                        NaN          NaN
# max        43.876501    -79.137575                        NaN          NaN
#
#         review_count       stars_y  state
# count   57047.000000  57047.000000  57047
# unique           NaN           NaN      2
# top              NaN           NaN     ON
# freq             NaN           NaN  57038
# mean      188.349624      3.729074    NaN
# std       284.562989      0.570702    NaN
# min         3.000000      1.000000    NaN
# 25%        41.500000      3.500000    NaN
# 50%       101.000000      4.000000    NaN
# 75%       216.000000      4.000000    NaN
# max      2121.000000      5.000000    NaN
#
# [11 rows x 24 columns]

# %% [markdown]
# #### ALERT: Multiple hours required for vectorization process. Data reduced further for testing/debugging and to be able to produce a modelling base for the project
# #### Current path: showcase with stars 1,2,3 only. Alternatively if keeping those codes, test on reducing to normalized records with all stars.
#
# ### (3). Classifying the dataset and splitting it into the reviews and stars:

# %%
# CLASSIFICATION
data_classes = data[(data['stars_x']==1) | (data['stars_x']==3) | (data['stars_x']==5)]
data_classes.head()
print(data_classes.shape)

# Seperate the dataset into X and Y for prediction
x = data_classes['text']
y = data_classes['stars_x']
print(x.head())
print(y.head())
# Out:
# (35096, 25)
# 4    All stars go to the decor and atmosphere of th...
# 5    Let's be honest, everyone's here for the photo...
# 6    This place is BEAUTIFUL! And the restaurant is...
# 8    If you are looking for a beautiful place to di...
# 9    Very great and unique experience dining at a f...
# Name: text, dtype: object
# 4    3.0
# 5    3.0
# 6    5.0
# 8    5.0
# 9    5.0
# Name: stars_x, dtype: float64

# %% [markdown]
# ### (4). Data Cleaning for modelling:
# We will now, define a function which will clean the dataset by removing stopwords and punctuations.

# %%
# CLEANING THE REVIEWS - REMOVAL OF STOPWORDS AND PUNCTUATION
def text_process(text):
    nopunc = [char for char in text if char not in string.punctuation]
    nopunc = ''.join(nopunc)
    return [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]

# %% [markdown]
# ### (5). Vectorization of the whole review set and and checking the sparse matrix:<br>

# %%
# CONVERTING THE WORDS INTO A VECTOR
vocab = CountVectorizer(analyzer=text_process).fit(x)

# %%
print(len(vocab.vocabulary_))
# Out:
# 60581

# %%
x = vocab.transform(x)
#Shape of the matrix:
print("Shape of the sparse matrix: ", x.shape)
#Non-zero occurences:
print("Non-Zero occurences: ",x.nnz)

# DENSITY OF THE MATRIX
density = (x.nnz/(x.shape[0]*x.shape[1]))*100
print("Density of the matrix = ",density)
# Out:
# Shape of the sparse matrix:  (35096, 60581)
# Non-Zero occurences:  1694056
# Density of the matrix =  0.07967713386663411

# %% [markdown]
# ### (6). Modelling:
#
# - Splitting the dataset X into training and testing set:

# %%
# SPLITTING THE DATASET INTO TRAINING SET AND TESTING SET
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=101)

# %% [markdown]
# - Using multiple Machine Algorithms to see which gives the best performance.

# %% [markdown]
# (1). Multinomial Naive Bayes - We are using Multinomial Naive Bayes over Gaussian because with sparse data, Gaussian Naive Bayes assumption of a normal distribution is not met and by default is not a good fit in this present case.

# %%
# Multinomial Naive Bayes
from sklearn.naive_bayes import MultinomialNB
mnb = MultinomialNB()
mnb.fit(x_train,y_train)
predmnb = mnb.predict(x_test)
print("Confusion Matrix for Multinomial Naive Bayes:")
print(confusion_matrix(y_test,predmnb))
print("Score:",round(accuracy_score(y_test,predmnb)*100,2))
print("Classification Report:",classification_report(y_test,predmnb))
# Out:
# Confusion Matrix for Multinomial Naive Bayes:
# [[ 899  247   37]
#  [ 153 1359  296]
#  [  52  267 3710]]
# Score: 85.01
# Classification Report:              precision    recall  f1-score   support
#
#         1.0       0.81      0.76      0.79      1183
#         3.0       0.73      0.75      0.74      1808
#         5.0       0.92      0.92      0.92      4029
#
# avg / total       0.85      0.85      0.85      7020

# %% [markdown]
# (2). Random Forest Classifier

# %%
# Random Forest
from sklearn.ensemble import RandomForestClassifier
rmfr = RandomForestClassifier()
rmfr.fit(x_train,y_train)
predrmfr = rmfr.predict(x_test)
print("Confusion Matrix for Random Forest Classifier:")
print(confusion_matrix(y_test,predrmfr))
print("Score:",round(accuracy_score(y_test,predrmfr)*100,2))
print("Classification Report:",classification_report(y_test,predrmfr))
# Out:
# Confusion Matrix for Random Forest Classifier:
# [[ 689  220  274]
#  [ 199  842  767]
#  [  63  323 3643]]
# Score: 73.7
# Classification Report:              precision    recall  f1-score   support
#
#         1.0       0.72      0.58      0.65      1183
#         3.0       0.61      0.47      0.53      1808
#         5.0       0.78      0.90      0.84      4029
#
# avg / total       0.73      0.74      0.72      7020

# %% [markdown]
# (3). Decision Tree

# %%
# Decision Tree
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
preddt = dt.predict(x_test)
print("Confusion Matrix for Decision Tree:")
print(confusion_matrix(y_test,preddt))
print("Score:",round(accuracy_score(y_test,preddt)*100,2))
print("Classification Report:",classification_report(y_test,preddt))
# Out:
# Confusion Matrix for Decision Tree:
# [[ 702  288  193]
#  [ 275  895  638]
#  [ 172  537 3320]]
# Score: 70.04
# Classification Report:              precision    recall  f1-score   support
#
#         1.0       0.61      0.59      0.60      1183
#         3.0       0.52      0.50      0.51      1808
#         5.0       0.80      0.82      0.81      4029
#
# avg / total       0.70      0.70      0.70      7020

# %% [markdown]
# (4). Support Vector Machines

# %%
# Support Vector Machine
from sklearn.svm import SVC
svm = SVC(random_state=101)
svm.fit(x_train,y_train)
predsvm = svm.predict(x_test)
print("Confusion Matrix for Support Vector Machines:")
print(confusion_matrix(y_test,predsvm))
print("Score:",round(accuracy_score(y_test,predsvm)*100,2))
print("Classification Report:",classification_report(y_test,predsvm))
# Out:
# Confusion Matrix for Support Vector Machines:
# [[   5    1 1177]
#  [   1    1 1806]
#  [   0    0 4029]]
# Score: 57.48
# Classification Report:              precision    recall  f1-score   support
#
#         1.0       0.83      0.00      0.01      1183
#         3.0       0.50      0.00      0.00      1808
#         5.0       0.57      1.00      0.73      4029
#
# avg / total       0.60      0.57      0.42      7020

# %% [markdown]
# (5). MULTILAYER PERCEPTRON CLASSIFIER

# %%
# MULTILAYER PERCEPTRON CLASSIFIER
from sklearn.neural_network import MLPClassifier
mlp = MLPClassifier()
mlp.fit(x_train,y_train)
predmlp = mlp.predict(x_test)
print("Confusion Matrix for Multilayer Perceptron Classifier:")
print(confusion_matrix(y_test,predmlp))
print("Score:",round(accuracy_score(y_test,predmlp)*100,2))
print("Classification Report:")
print(classification_report(y_test,predmlp))
# Out:
# Confusion Matrix for Multilayer Perceptron Classifier:
# [[ 945  182   56]
#  [ 156 1306  346]
#  [  40  266 3723]]
# Score: 85.1
# Classification Report:
#              precision    recall  f1-score   support
#
#         1.0       0.83      0.80      0.81      1183
#         3.0       0.74      0.72      0.73      1808
#         5.0       0.90      0.92      0.91      4029
#
# avg / total       0.85      0.85      0.85      7020

# %% [markdown]
# ### RESULTS - From the above algorithm modelling, we can see that:
# - Multilayer Perceptron = 85.1%
# - Multinomial Naive Bayes = 85.01%
# - Random Forest Classifier = 73.7%
# - Decision Tree = 70.07%
# - Support Vector Machine  = 57.48%

# %% [markdown]
# ### Multilayer Perceptron Classifier has the best score, let us use it to predict a random positive review, a random average review and a random negative review!

# %% [markdown]
# ### (7) Predicting rating for sample reviews

# %%
#Locate review samples
data.head(100)
# Out:
#                        _id_x             business_id  cool  \
# 0   5d34af2f05c8a038caf1cb40  3a7Qby_IX7sU7O6ZsQZeOQ     0
# 1   5d34af3605c8a038caf1dfe5  3a7Qby_IX7sU7O6ZsQZeOQ     1
# 2   5d34af2505c8a038caf1a198  3a7Qby_IX7sU7O6ZsQZeOQ     0
# 3   5d34af5205c8a038caf20309  3a7Qby_IX7sU7O6ZsQZeOQ     0
# 4   5d34af6c05c8a038caf22ae0  3a7Qby_IX7sU7O6ZsQZeOQ     0
# 5   5d34afc805c8a038caf262c5  3a7Qby_IX7sU7O6ZsQZeOQ     0
# 6   5d34b00405c8a038caf28272  3a7Qby_IX7sU7O6ZsQZeOQ     0
# 7   5d34b03905c8a038caf2ac22  3a7Qby_IX7sU7O6ZsQZeOQ     0
# 8   5d34b04f05c8a038caf2ccf4  3a7Qby_IX7sU7O6ZsQZeOQ     0
# 9   5d34b05305c8a038caf2d8d5  3a7Qby_IX7sU7O6ZsQZeOQ     0
# 10  5d34b08e05c8a038caf2fc9b  3a7Qby_IX7sU7O6ZsQZeOQ     0
# 11  5d34b0d405c8a038caf31d7c  3a7Qby_IX7sU7O6ZsQZeOQ     0
# 12  5d34b0ab05c8a038caf30916  3a7Qby_IX7sU7O6ZsQZeOQ    12
# 13  5d34b12205c8a038caf357c0  3a7Qby_IX7sU7O6ZsQZeOQ     0
# 14  5d34b12905c8a038caf360c5  3a7Qby_IX7sU7O6ZsQZeOQ     0
# 15  5d34b13705c8a038caf3852d  3a7Qby_IX7sU7O6ZsQZeOQ     6
# 16  5d34b13805c8a038caf38c9a  3a7Qby_IX7sU7O6ZsQZeOQ     0
#
#                                                  text  useful  \
# 0   The service here is impeccable. Our waitress w...       0
# 1   Decided to come check out the furniture and se...       3
# 2   My best friend and I came here to see what the...       4
# 3   I went there for lunch today.  They've changed...       0
# 4   All stars go to the decor and atmosphere of th...       3
# 5   Let's be honest, everyone's here for the photo...       2
# 6   This place is BEAUTIFUL! And the restaurant is...       1
# 7   Located at Yorkdale Mall, the Restoration Hard...       0
# 8   If you are looking for a beautiful place to di...       0
# 9   Very great and unique experience dining at a f...       0
# 10  Decor is nice. But that's about it. Food was b...       2
# 11  Yes it's beautiful and Instagrammable! We had ...       1
# 12  [LOCATION] - 4/5\r\nThis place is located in Y...      24
# 13  Excellent atmosphere if you're looking for a p...       0
# 14  This is a small restaurant at the front of the...       0
# 15  So I have been seeing this place mostly on ins...      12
# 16  The RH cafe is truly awesome! From the ambienc...       0
# 17  Came here for late lunch on Boxing Day. The wa...       0
# 18  I really enjoyed my experience at the RH cafe....       8
# 19  This is a furniture shop where you can eat and...       3
# 20  Got the lobster roll with salad for $31. Not a...       0
# 21  Beautiful decor. Ridiculous wait times.\r\n\r\...       3
# 22  From the ambiance to the service and food qual...       1
# 23  The interior decor was DIVINE! That alone was ...       0
# 24  Came back again for their grilled cheese but t...       2
# 25  3.5 \r\n\r\nYou've seen it on Instagram, but h...       1
# 26  This place is absolutely gorgeous from end to ...       0
# 27  Wait was 1.5 hours to get table, then another ...       0
# 28  Excellent Restaurant!\r\n\r\nWe have eaten at ...       0
# 29  Came here on a Saturday afternoon and was told...       0
# ..                                                ...     ...
# 70  The breakfast itself is pretty decent. It's yo...       0
# 71  I usually don't comment much on breakfast plac...       2
# 72  Used to constantly go here, but a month later,...       0
# 73  This is your neighbourhood greasy spoon diner....       0
# 74  Oh my god the cinnamon bun pancakes were DELIC...       0
# 75  This Canadian nook was a pleasant suprise and ...       1
# 76  The best vegetarian food in Toronto. I usually...       0
# 77  I am so glad I tried this place out.   I had t...       0
# 78  Consistently great tasting food! Love the BBQ ...       0
# 79  This was such a great place !!! Everything was...       0
# 80  I've only been here a couple of times because ...       0
# 81  Amazing restaurant that combines carribean fla...       1
# 82  One must love this vegetarian food! Cooked wit...       0
# 83  Amazing food! Had the roasted vege wrap and th...       0
# 84  So good I ended up devouring most of it before...       0
# 85  My go-to place if I want a nice bowl of soup. ...       0
# 86  I got the roasted free range chicken (mild) an...       0
# 87  Ravi Soups was FANTASTIC!! My wife and I each ...       0
# 88  Awesome wraps and soups. Perfect for a cold da...       0
# 89  I had the curried lamb wrap and soup special R...       0
# 90  This place is a complete hit and miss dependin...       0
# 91  I love this place. I've tried everything on th...       0
# 92  Tried the apricot soup. Very filling and amazi...       0
# 93  Came here with friends after catching a movie ...       2
# 94  Three stars for food and an extra star for the...       0
# 95  I love this spot! Steak wrap is delicious and ...       0
# 96  Great lunch spot in Toronto! I got the Soup an...       0
# 97  Love the food- always fresh and new options av...       0
# 98  Soups and wraps galore! I had a soup and wrap ...       1
# 99  I used to really enjoy getting wraps from here...       1
#
#                    user_id  ...    \
# 0   CZqHG0JtP6pxK2ox7zpwVQ  ...
# 1   TFxeEvpjMNQ3AWL49iMwtA  ...
# 2   HxkWE8b1bJbSc4Ihmgy5dQ  ...
# 3   BV2TQDbbgC5Mwgyoh3CHDA  ...
# 4   Fsl7fnXttgugpoyuCJ0zkg  ...
# 5   T5BOAvuPsNAhjYTFkRqZ1Q  ...
# 6   l55_yghqjkJQ2TzRMbNsag  ...
# 7   wdeWt5VqTW26PAeQsVg73g  ...
# 8   LtyBdOAFYXa4NC9l_WWn1A  ...
# 9   pae5DbzPtBfFQlceFwo1QQ  ...
# 10  zyg4-MFtfPWmwucVazSjfw  ...
# 11  BCjsgRFDCxGQHr0hVlwqvg  ...
# 12  vyAkrxESZM9irxCXw_BvzA  ...
# 13  vf-1VdjEL5nGjuFn7yhRQg  ...
# 14  IhV5kw-KWMyPNuhzTrT_-g  ...
# 15  Z09rco1enQXNCd9H0u7kvg  ...
# 16  UkORgogyaAWs7IyETYPUcQ  ...
# 17  JVQYn_YQD9RAXEpw07NIdg  ...
# 18  YEDnTf7d6RyXKEHDGqi9tg  ...
# 19  mI4JiIhxbL_oNC6Dkd7pZg  ...
# 20  -zXNnEJ1WmYn0Yy-fDje0A  ...
# 21  LNNQSUtoYEtf0AsGQRwfJQ  ...
# 22  s1XTZINUXibQEfbCvRKBMg  ...
# 23  haVGGRqlOyPfhwfXWvxSRw  ...
# 24  TKtfZw4vjbaLP6KzllK8Vw  ...
# 25  wWHeaOS28fnCnFN1Pmo3xg  ...
# 26  9JZ7jyVvfAwOa2ExotIkhw  ...
# 27  jENfZwLx_FfXK02CuLw0TQ  ...
# 28  iMP01u2AfVHZrxSPz1Dj2A  ...
# 29  TKtfZw4vjbaLP6KzllK8Vw  ...
# ..                     ...  ...
# 70  5T4yhxuNfKeMkUqZU9VeYg  ...
# 71  wtmCr-aVN5XqM3n8NuntMw  ...
# 72  4omSmj--1sLfRfRijg6kRg  ...
# 73  C4wnx5iBJ13D5lVgKTGWtQ  ...
# 74  5V5Hya9CjxK3WXqloJPEKg  ...
# 75  MOxxsZ5WQnrt1g6bxO049Q  ...
# 76  1j7RTbKun6Hlj7jNpU9qmg  ...
# 77  OAUd0tO-xINwkgnpthIbVA  ...
# 78  ws6Rn6bP-W4cqHLuafCH4A  ...
# 79  NMofgMuqWVu5rNvVh4SeLA  ...
# 80  jSbXY_rno4hYHQCFftsWXg  ...
# 81  O0evs8847ecEkeFMEuK4PA  ...
# 82  XVKgw7GH5gbEPmWnvhBlPA  ...
# 83  N4H7duF2n3tX6PCWjsGpAQ  ...
# 84  HV6pgnVdongJWet-dUjSpQ  ...
# 85  uoeENUO7Bkw5OwO_KHV-Rg  ...
# 86  IlGVrBMNUnIjn7VzX67AyQ  ...
# 87  gtuRablOmw5O08QoKbn0fQ  ...
# 88  2W_RyL1ElT65sKhPTBhwPA  ...
# 89  uTu74kG-S_54TpMNtBC04w  ...
# 90  1cSWJ_PVcEl-4XyEY0b7gA  ...
# 91  TcviSKeDoUdM_0JHfnAPlQ  ...
# 92  xV3JJRXe5dj6UPzJ_MD7JA  ...
# 93  mwi6OSsC4fdTc7E-LHc0SQ  ...
# 94  YRpt761-BvFVNI-PiJpu9g  ...
# 95  u9Udk2CqXuupjdhelIKu1w  ...
# 96  qwwm1RH-B50FktJ0gzOe_Q  ...
# 97  9s3nLll5503tDwvzZbZNoA  ...
# 98  azZdNaUfeb8J9H1k_aoWJQ  ...
# 99  GG4QPrqU7wxL8WVXuzozMg  ...
#
#                                                 hours is_open   latitude  \
# 0   {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 1   {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 2   {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 3   {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 4   {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 5   {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 6   {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 7   {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 8   {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 9   {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 10  {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 11  {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 12  {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 13  {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 14  {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 15  {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 16  {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 17  {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 18  {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 19  {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 20  {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 21  {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 22  {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 23  {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 24  {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 25  {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 26  {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 27  {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 28  {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# 29  {'Monday': '0:0-0:0', 'Tuesday': '10:0-20:0', ...       1  43.724684
# ..                                                ...     ...        ...
# 70  {'Monday': '7:0-14:30', 'Tuesday': '7:0-14:30'...       1  43.788145
# 71  {'Monday': '7:0-14:30', 'Tuesday': '7:0-14:30'...       1  43.788145
# 72  {'Monday': '7:0-14:30', 'Tuesday': '7:0-14:30'...       1  43.788145
# 73  {'Monday': '7:0-14:30', 'Tuesday': '7:0-14:30'...       1  43.788145
# 74  {'Monday': '7:0-14:30', 'Tuesday': '7:0-14:30'...       1  43.788145
# 75  {'Monday': '7:0-14:30', 'Tuesday': '7:0-14:30'...       1  43.788145
# 76  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...       1  43.666774
# 77  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...       1  43.666774
# 78  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...       1  43.666774
# 79  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...       1  43.666774
# 80  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...       1  43.666774
# 81  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...       1  43.666774
# 82  {'Monday': '11:0-21:0', 'Tuesday': '11:0-21:0'...       1  43.666774
# 83  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...       1  43.647585
# 84  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...       1  43.647585
# 85  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...       1  43.647585
# 86  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...       1  43.647585
# 87  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...       1  43.647585
# 88  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...       1  43.647585
# 89  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...       1  43.647585
# 90  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...       1  43.647585
# 91  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...       1  43.647585
# 92  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...       1  43.647585
# 93  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...       1  43.647585
# 94  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...       1  43.647585
# 95  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...       1  43.647585
# 96  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...       1  43.647585
# 97  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...       1  43.647585
# 98  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...       1  43.647585
# 99  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...       1  43.647585
#
#     longitude                                name postal_code  review_count  \
# 0  -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# 1  -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# 2  -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# 3  -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# 4  -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# 5  -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# 6  -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# 7  -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# 8  -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# 9  -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# 10 -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# 11 -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# 12 -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# 13 -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# 14 -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# 15 -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# 16 -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# 17 -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# 18 -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# 19 -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# 20 -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# 21 -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# 22 -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# 23 -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# 24 -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# 25 -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# 26 -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# 27 -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# 28 -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# 29 -79.454173                   RH Courtyard Cafe     M6A 2T9            82
# ..        ...                                 ...         ...           ...
# 70 -79.329492  Rosemary & Thyme Family Restaurant     M2J 4A8            34
# 71 -79.329492  Rosemary & Thyme Family Restaurant     M2J 4A8            34
# 72 -79.329492  Rosemary & Thyme Family Restaurant     M2J 4A8            34
# 73 -79.329492  Rosemary & Thyme Family Restaurant     M2J 4A8            34
# 74 -79.329492  Rosemary & Thyme Family Restaurant     M2J 4A8            34
# 75 -79.329492  Rosemary & Thyme Family Restaurant     M2J 4A8            34
# 76 -79.412066                 One Love Vegetarian     M5R 3G2            75
# 77 -79.412066                 One Love Vegetarian     M5R 3G2            75
# 78 -79.412066                 One Love Vegetarian     M5R 3G2            75
# 79 -79.412066                 One Love Vegetarian     M5R 3G2            75
# 80 -79.412066                 One Love Vegetarian     M5R 3G2            75
# 81 -79.412066                 One Love Vegetarian     M5R 3G2            75
# 82 -79.412066                 One Love Vegetarian     M5R 3G2            75
# 83 -79.392032                          Ravi Soups     M5V 1R1           332
# 84 -79.392032                          Ravi Soups     M5V 1R1           332
# 85 -79.392032                          Ravi Soups     M5V 1R1           332
# 86 -79.392032                          Ravi Soups     M5V 1R1           332
# 87 -79.392032                          Ravi Soups     M5V 1R1           332
# 88 -79.392032                          Ravi Soups     M5V 1R1           332
# 89 -79.392032                          Ravi Soups     M5V 1R1           332
# 90 -79.392032                          Ravi Soups     M5V 1R1           332
# 91 -79.392032                          Ravi Soups     M5V 1R1           332
# 92 -79.392032                          Ravi Soups     M5V 1R1           332
# 93 -79.392032                          Ravi Soups     M5V 1R1           332
# 94 -79.392032                          Ravi Soups     M5V 1R1           332
# 95 -79.392032                          Ravi Soups     M5V 1R1           332
# 96 -79.392032                          Ravi Soups     M5V 1R1           332
# 97 -79.392032                          Ravi Soups     M5V 1R1           332
# 98 -79.392032                          Ravi Soups     M5V 1R1           332
# 99 -79.392032                          Ravi Soups     M5V 1R1           332
#
#     stars_y  state length
# 0       4.0     ON    630
# 1       4.0     ON    846
# 2       4.0     ON   1453
# 3       4.0     ON    238
# 4       4.0     ON    348
# 5       4.0     ON    333
# 6       4.0     ON    534
# 7       4.0     ON   1168
# 8       4.0     ON    799
# 9       4.0     ON    402
# 10      4.0     ON    243
# 11      4.0     ON    935
# 12      4.0     ON   1321
# 13      4.0     ON   1238
# 14      4.0     ON   1008
# 15      4.0     ON    618
# 16      4.0     ON    235
# 17      4.0     ON    673
# 18      4.0     ON   2128
# 19      4.0     ON    656
# 20      4.0     ON    282
# 21      4.0     ON   1851
# 22      4.0     ON    404
# 23      4.0     ON    509
# 24      4.0     ON    623
# 25      4.0     ON   1395
# 26      4.0     ON   1057
# 27      4.0     ON    328
# 28      4.0     ON    426
# 29      4.0     ON    507
# ..      ...    ...    ...
# 70      4.0     ON    253
# 71      4.0     ON    726
# 72      4.0     ON    793
# 73      4.0     ON    396
# 74      4.0     ON    348
# 75      4.0     ON    640
# 76      4.5     ON    161
# 77      4.5     ON    269
# 78      4.5     ON    102
# 79      4.5     ON    235
# 80      4.5     ON    394
# 81      4.5     ON    823
# 82      4.5     ON    121
# 83      4.5     ON    148
# 84      4.5     ON    482
# 85      4.5     ON    248
# 86      4.5     ON    505
# 87      4.5     ON    617
# 88      4.5     ON    157
# 89      4.5     ON    278
# 90      4.5     ON    392
# 91      4.5     ON    347
# 92      4.5     ON    128
# 93      4.5     ON    263
# 94      4.5     ON    180
# 95      4.5     ON    133
# 96      4.5     ON    205
# 97      4.5     ON    139
# 98      4.5     ON    663
# 99      4.5     ON    384
#
# [100 rows x 25 columns]

# %%
# POSITIVE REVIEW
pr = data['text'][73]
print(pr)
print("Actual Rating: ",data['stars_x'][73])
pr_t = vocab.transform([pr])
print("Predicted Rating:")
mlp.predict(pr_t)[0]
# Out:
# This is your neighbourhood greasy spoon diner. It gets busy on weekends so be prepared to wait. Excellent and personable service with a cozy and old school vibe. I had the gyro omlette which was tasty and had a unique flavour as it was served with tzaziki. Large portions, bottomless coffee as you would expect. A solid 4 stars from me and worth checking out over chains like eggsmart and cora's.
# Actual Rating:  4.0
# Predicted Rating:
# 5.0

# %%
# AVERAGE REVIEW
ar = data['text'][14]
print(ar)
print("Actual Rating: ",data['stars_x'][14])
ar_t = vocab.transform([ar])
print("Predicted Rating:")
mlp.predict(ar_t)[0]
# Out:
# This is a small restaurant at the front of the new restoration hardware store in Yorkdale mall. We came for lunch and there was about a 20-30 min wait so we put down our number and just walked around the mall. I'd suggest making a reservation in the future as this is the second time I've been confronted with a wait.
#
# The food choices are roughly Western style-esque brunch with sandwiches, salads, fries, etc. I wasn't too pleased to see that all the salads needed meat added to them- with the lowest starting at $8 for chicken.
#
# We both got a salad, I got the arugula with chicken and we had fries to split. The food came out promptly and it tasted amazing!! I didn't get a lot of chicken but my friend who added smoked salmon and avocado to her salad got a heaping of both!
#
# Overall the decorum of the place is so peaceful and beautiful. The seats range from single chairs to sofas for larger groups. There's lots of natural lighting. However, I would hesitate to come back again for the price!!
# Actual Rating:  3.0
# Predicted Rating:
# 3.0

# %%
# NEGATIVE REVIEW
nr = data['text'][90]
print(nr)
print("Actual Rating: ",data['stars_x'][90])
nr_t = vocab.transform([nr])
print("Predicted Rating:")
mlp.predict(nr_t)[0]
# Out:
# This place is a complete hit and miss depending on when you visit. I just finished throwing out a chicken wrap consisting of dry, inedible chicken scraps. The soup was good, as usual, but the crappy wraps ruined the entire experience.  Weekends are generally a bad time to visit. If you are curious to try this place out, best time to go in terms of food quality is lunchtime during weekdays.
# Actual Rating:  1.0
# Predicted Rating:
# 1.0

# %%
count = data['stars_x'].value_counts()
print(count)
# Out:
# 5.0    20102
# 4.0    16898
# 3.0     9097
# 1.0     5897
# 2.0     5053
# Name: stars_x, dtype: int64

# %% [markdown]
# ### Conclusion and Observation
# - From the above, we can see that the positive reviews tend to lean towards 5 stars. This might be due to the dataset having more positive reviews as compared to negative reviews. <br>
# - Normalizing the dataset to have equal number of reviews might correct this.
# - We are able to accurate predict the user star rating according to their reviews
#
# ### Next steps
# - Review the vectorization process. Process takes too long.
# - Review the whole modelling concept. Star rating prediction based on current ratings. Reasearch to undertake for rating based on reviews sentiment alone.
# - Wrap everything up. Create detailed document and presentation brief.
